# %%
x = 5
y = 6

print(x is y)
print(x is not y)
print(id(x))
print(id(y))
# Out:
# False
# True
# 140709051724840
# 140709051724872

# %%
x = 5
y = 5

print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 140709051724840
# 140709051724840

# %%
x = -5
y = -5

print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 140709051724520
# 140709051724520

# %%
x = 256
y = 256

print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 140709051732872
# 140709051732872

# %%
x = "kalana"
y = "kalana"

print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 2238630376960
# 2238630376960
