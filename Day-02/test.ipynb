# %%
lst = [1,2,3,4]
lst[1:3] = [[2,3]]
print(lst)
# Out:
# [1, [2, 3], 4]

# %%
data = {
  'x' : {
    'y':[1,2,{
      'z':3
    }]
  }
}

value = data['x']['y'][2]['z']
print(value)
# Out:
# 3

# %%
lst = [1,2,3]
lst[len(lst):] = lst
print(lst)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
lst = [1,2,3,4,5]
lst[ : : 2] = [0,0,0]
print(lst)
# Out:
# [0, 2, 0, 4, 0]

# %%
t = ([1,2],[3,4])
t[0][:] = [5,6]
print(t[0])
# Out:
# [5, 6]

# %%
x = [1,2,3]
y = (x,x)

x.append(4)
print(y[0][-1])
# Out:
# 4

# %%
t = (1,2,[3,4])
t[2].extend([5])

print(t)
print(t[-1][-2])
# Out:
# (1, 2, [3, 4, 5])
# 4

# %%
a = {1,2,3}
b = {3,2,1}

c = a == b
d = a is b

print(c)
print(d)
# Out:
# True
# False

# %%
a = 10
b = 4

print(a & b)
print(a ^ b)
print((a & b) | (a ^ b))
# Out:
# 0
# 14
# 14

# %%
x = 10
y = 5

z = x == y

print(z)
# Out:
# False

# %%
d = {
  'x' : 1,
  'y' : 2
}

d.update({'x':10,'z':3})
print(d)
# Out:
# {'x': 10, 'y': 2, 'z': 3}

# %%
a = [10,20,30,40]

a[1:3] = [99]
print(a)
# Out:
# [10, 99, 40]

# %%
nums = [1,2,3,4]
nums.append([5,6])

print(nums)
print(len(nums))
# Out:
# [1, 2, 3, 4, [5, 6]]
# 5

# %%
result = not 5 + 2 * 3 > 10 // 2 and 8 % 3 == 2

print(result)
# Out:
# False

# %%
x = ['a','b','c']

y = x.pop(1)

print(y,x)
# Out:
# b ['a', 'c']
