# %%
x = 10

result = "Even" if x % 2 == 0 else "Odd"
print(result)
# Out:
# Even

# %%
#Quiz-06
num = float(input("Enter a number: "))

result = num if num >= 0 else -num
print(result)
# Out:
# 13.0
